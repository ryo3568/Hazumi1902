# %%
import pandas as pd 
import glob

# %%
FILE_PATH = "/home/ryoyanagimoto/Hazumi1902/dumpfiles/*.csv"
files = glob.glob(FILE_PATH)

S = set()
col_test1 = ['Unnamed: 972', 'Unnamed: 971', 'Unnamed: 970', '無言', '名詁E形容詁E感動詁E副詁Elabel']

for i, file in enumerate(files):
    df = pd.read_csv(file)
    df_col = df.columns.values 
    if set(df_col) >= set(col_test1):
        print(file)
# Out:
# /home/ryoyanagimoto/Hazumi1902/dumpfiles/1902F4009.csv
# /home/ryoyanagimoto/Hazumi1902/dumpfiles/1902F3001.csv
# /home/ryoyanagimoto/Hazumi1902/dumpfiles/1902M4001.csv
# /home/ryoyanagimoto/Hazumi1902/dumpfiles/1902F2002.csv
# /home/ryoyanagimoto/Hazumi1902/dumpfiles/1902F4011.csv
# /home/ryoyanagimoto/Hazumi1902/dumpfiles/1902M5001.csv
# /home/ryoyanagimoto/Hazumi1902/dumpfiles/1902F4006.csv
# /home/ryoyanagimoto/Hazumi1902/dumpfiles/1902F4004.csv

# %%
df2 = pd.read_csv("/home/ryoyanagimoto/Hazumi1902/dumpfiles/1902F2002.csv")

col = np.array(df2.columns.tolist()) 
print(col)
# Out:
# ['start(exchange)[ms]' 'end(system)[ms]' 'end(exchange)[ms]'
#  'kinectstart(exchange)[ms]' 'kinectend(system)[ms]'
#  'kinectend(exchange)[ms]' 'SS_ternary' 'TC_ternary' 'TS_ternary' 'SS'
#  'TC1' 'TC2' 'TC3' 'TC4' 'TC5' 'TS1' 'TS2' 'TS3' 'TS4' 'TS5'
#  'pcm_RMSenergy_sma_max' 'pcm_RMSenergy_sma_min' 'pcm_RMSenergy_sma_range'
#  'pcm_RMSenergy_sma_maxPos' 'pcm_RMSenergy_sma_minPos'
#  'pcm_RMSenergy_sma_amean' 'pcm_RMSenergy_sma_linregc1'
#  'pcm_RMSenergy_sma_linregc2' 'pcm_RMSenergy_sma_linregerrQ'
#  'pcm_RMSenergy_sma_stddev' 'pcm_RMSenergy_sma_skewness'
#  'pcm_RMSenergy_sma_kurtosis' 'pcm_fftMag_mfcc_sma[1]_max'
#  'pcm_fftMag_mfcc_sma[1]_min' 'pcm_fftMag_mfcc_sma[1]_range'
#  'pcm_fftMag_mfcc_sma[1]_maxPos' 'pcm_fftMag_mfcc_sma[1]_minPos'
#  'pcm_fftMag_mfcc_sma[1]_amean' 'pcm_fftMag_mfcc_sma[1]_linregc1'
#  'pcm_fftMag_mfcc_sma[1]_linregc2' 'pcm_fftMag_mfcc_sma[1]_linregerrQ'
#  'pcm_fftMag_mfcc_sma[1]_stddev' 'pcm_fftMag_mfcc_sma[1]_skewness'
# ...

# %%
df = pd.read_csv('/home/ryoyanagimoto/Hazumi1902/dumpfiles/1902F2001.csv') 

col = np.array(df.columns.tolist()) 
print(col)
# Out:
# ['start(exchange)[ms]' 'end(system)[ms]' 'end(exchange)[ms]'
#  'kinectstart(exchange)[ms]' 'kinectend(system)[ms]'
#  'kinectend(exchange)[ms]' 'SS_ternary' 'TC_ternary' 'TS_ternary' 'SS'
#  'TC1' 'TC2' 'TC3' 'TC4' 'TC5' 'TS1' 'TS2' 'TS3' 'TS4' 'TS5'
#  'pcm_RMSenergy_sma_max' 'pcm_RMSenergy_sma_min' 'pcm_RMSenergy_sma_range'
#  'pcm_RMSenergy_sma_maxPos' 'pcm_RMSenergy_sma_minPos'
#  'pcm_RMSenergy_sma_amean' 'pcm_RMSenergy_sma_linregc1'
#  'pcm_RMSenergy_sma_linregc2' 'pcm_RMSenergy_sma_linregerrQ'
#  'pcm_RMSenergy_sma_stddev' 'pcm_RMSenergy_sma_skewness'
#  'pcm_RMSenergy_sma_kurtosis' 'pcm_fftMag_mfcc_sma[1]_max'
#  'pcm_fftMag_mfcc_sma[1]_min' 'pcm_fftMag_mfcc_sma[1]_range'
#  'pcm_fftMag_mfcc_sma[1]_maxPos' 'pcm_fftMag_mfcc_sma[1]_minPos'
#  'pcm_fftMag_mfcc_sma[1]_amean' 'pcm_fftMag_mfcc_sma[1]_linregc1'
#  'pcm_fftMag_mfcc_sma[1]_linregc2' 'pcm_fftMag_mfcc_sma[1]_linregerrQ'
#  'pcm_fftMag_mfcc_sma[1]_stddev' 'pcm_fftMag_mfcc_sma[1]_skewness'
# ...
