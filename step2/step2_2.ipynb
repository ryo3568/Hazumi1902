# %%
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import glob
from sklearn import datasets
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import confusion_matrix
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.metrics import classification_report

# %%
def clean(df, flag):

    col_train = ['start(exchange)[ms]', 'end(system)[ms]', 'end(exchange)[ms]',\
    'kinectstart(exchange)[ms]', 'kinectend(system)[ms]',\
    'kinectend(exchange)[ms]', 'SS_ternary', 'TC_ternary', 'TS_ternary', 'SS',\
    'TC1', 'TC2', 'TC3', 'TC4', 'TC5', 'TS1', 'TS2', 'TS3', 'TS4', 'TS5']
    col_test1 = ['Unnamed: 972', 'Unnamed: 971', 'Unnamed: 970', '無言', '名詁E形容詁E感動詁E副詁Elabel']
    col_test2 = ['adjective', 'no_utterance', 'adverbs', 'noun', 'interjection']

    df_col = df.columns.values 

    if flag:
        df = df.drop(col_train, axis=1) 
        df = df.drop(col_test1, axis=1) 
        df = df.drop(col_test2, axis=1)
    else:
        df = df.drop(col_train, axis=1) 
        if set(df_col) >= set(col_test1):
            df = df.drop(col_test1, axis=1)
        else:
            df = df.drop(col_test2, axis=1)
    return df.values

# %%
def louocv(files, testfile):
    #train_dfが空かどうか（空のtrain_dfにconcat()できないための対応）
    flag = True

    for file in files:
        if file == testfile:
            test_df = pd.read_csv(file)
        else:
            if flag:
                train_df = pd.read_csv(file)
                flag = False 
            else:
                tmp_df = pd.read_csv(file)
                train_df = pd.concat([train_df, tmp_df])


    return train_df, test_df

# %%
FILE_PATH = "/home/ryoyanagimoto/Hazumi1902/dumpfiles/*.csv"
files = glob.glob(FILE_PATH)

test_preds = []
test_ans = []

for testfile in files:
    train_df, test_df = louocv(files, testfile)

    #train_data = train_df.drop(col, axis=1).values 
    train_data = clean(train_df, True)
    train_target = train_df['TS_ternary'].values 


    #test_data = test_df.drop(col, axis=1).values 
    test_data = clean(test_df, False)
    test_target = test_df['TS_ternary'].values 

    x_train, x_valid, y_train, y_valid = train_test_split(train_data, train_target, shuffle=True)

    scaler = StandardScaler()
    scaler.fit(x_train) 

    x_train = scaler.transform(x_train) 
    x_valid = scaler.transform(x_valid) 
    test_data = scaler.transform(test_data) 

    x_train = torch.from_numpy(x_train).to(torch.float)
    y_train = torch.from_numpy(y_train).to(torch.long)
    x_valid = torch.from_numpy(x_valid).to(torch.float)
    y_valid = torch.from_numpy(y_valid).to(torch.long)

    x_test = torch.from_numpy(test_data).to(torch.float)
    y_test = torch.from_numpy(test_target).to(torch.long)

    train_dataset = TensorDataset(x_train, y_train)
    valid_dataset = TensorDataset(x_valid, y_valid)

    batch_size = 16
    train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

    class Net(nn.Module):    
        def __init__(self):
            super(Net, self).__init__()
            self.fc1 = nn.Linear(1458, 50)
            self.fc2 = nn.Linear(50, 3)
    
        def forward(self, x):
            x = self.fc1(x)
            x = F.relu(x)
            x = self.fc2(x)
            x = F.softmax(x, dim=1)
            return x

    net = Net()

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=0.01)

    # エポック数
    num_epochs = 10

    # 学習時と検証時で分けるためディクショナリを用意
    dataloaders_dict = {
        'train': train_dataloader,
        'val': valid_dataloader
    }

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')
        
        for phase in ['train', 'val']:
            
            if phase == 'train':
                # モデルを訓練モードに設定
                net.train()
            else:
                # モデルを推論モードに設定
                net.eval()
            
            # 損失和
            epoch_loss = 0.0
            # 正解数
            epoch_corrects = 0
            
            # DataLoaderからデータをバッチごとに取り出す
            for inputs, labels in dataloaders_dict[phase]:
                
                # optimizerの初期化
                optimizer.zero_grad()
                
                # 学習時のみ勾配を計算させる設定にする
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = net(inputs)
                    
                    # 損失を計算
                    loss = criterion(outputs, labels)
                    
                    # ラベルを予測
                    _, preds = torch.max(outputs, 1)
                    
                    # 訓練時はバックプロパゲーション
                    if phase == 'train':
                        # 逆伝搬の計算
                        loss.backward()
                        # パラメータの更新
                        optimizer.step()
                    
                    # イテレーション結果の計算
                    # lossの合計を更新
                    # PyTorchの仕様上各バッチ内での平均のlossが計算される。
                    # データ数を掛けることで平均から合計に変換をしている。
                    # 損失和は「全データの損失/データ数」で計算されるため、
                    # 平均のままだと損失和を求めることができないため。
                    epoch_loss += loss.item() * inputs.size(0)
                    
                    # 正解数の合計を更新
                    epoch_corrects += torch.sum(preds == labels.data)

            # epochごとのlossと正解率を表示
            epoch_loss = epoch_loss / len(dataloaders_dict[phase].dataset)
            epoch_acc = epoch_corrects.double() / len(dataloaders_dict[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

    pred = net(x_test)
    test_ans = test_ans + test_target.tolist()
    test_preds = test_preds + torch.argmax(pred, dim=1).tolist()
# Out:
# Epoch 1/10
# -------------
# train Loss: 1.0118 Acc: 0.6115
# val Loss: 0.9527 Acc: 0.6918
# Epoch 2/10
# -------------
# train Loss: 0.9060 Acc: 0.7107
# val Loss: 0.8949 Acc: 0.7079
# Epoch 3/10
# -------------
# train Loss: 0.8567 Acc: 0.7376
# val Loss: 0.8669 Acc: 0.7115
# Epoch 4/10
# -------------
# train Loss: 0.8305 Acc: 0.7496
# val Loss: 0.8524 Acc: 0.7133
# Epoch 5/10
# -------------
# train Loss: 0.8150 Acc: 0.7537
# val Loss: 0.8439 Acc: 0.7204
# Epoch 6/10
# -------------
# train Loss: 0.8042 Acc: 0.7597
# val Loss: 0.8376 Acc: 0.7276
# Epoch 7/10
# -------------
# train Loss: 0.7958 Acc: 0.7663
# val Loss: 0.8329 Acc: 0.7330
# Epoch 8/10
# -------------
# train Loss: 0.7889 Acc: 0.7747
# val Loss: 0.8291 Acc: 0.7366
# Epoch 9/10
# -------------
# train Loss: 0.7828 Acc: 0.7788
# val Loss: 0.8259 Acc: 0.7312
# Epoch 10/10
# -------------
# train Loss: 0.7773 Acc: 0.7806
# val Loss: 0.8230 Acc: 0.7312
# Epoch 1/10
# -------------
# train Loss: 1.0249 Acc: 0.5966
# val Loss: 0.9517 Acc: 0.6963
# Epoch 2/10
# -------------
# train Loss: 0.9276 Acc: 0.6908
# val Loss: 0.8876 Acc: 0.7194
# Epoch 3/10
# -------------
# train Loss: 0.8790 Acc: 0.7044
# val Loss: 0.8546 Acc: 0.7318
# Epoch 4/10
# -------------
# train Loss: 0.8513 Acc: 0.7210
# val Loss: 0.8360 Acc: 0.7353
# Epoch 5/10
# -------------
# train Loss: 0.8334 Acc: 0.7387
# val Loss: 0.8240 Acc: 0.7371
# train Loss: 0.8079 Acc: 0.7553
# val Loss: 0.8219 Acc: 0.7367
# Epoch 7/10
# -------------
# train Loss: 0.7984 Acc: 0.7612
# val Loss: 0.8159 Acc: 0.7385
# Epoch 8/10
# -------------
# train Loss: 0.7905 Acc: 0.7665
# val Loss: 0.8109 Acc: 0.7473
# Epoch 9/10
# -------------
# train Loss: 0.7837 Acc: 0.7706
# val Loss: 0.8070 Acc: 0.7509
# Epoch 10/10
# -------------
# train Loss: 0.7777 Acc: 0.7765
# val Loss: 0.8043 Acc: 0.7509
# Epoch 1/10
# -------------
# train Loss: 1.0424 Acc: 0.5380
# val Loss: 0.9587 Acc: 0.6858
# Epoch 2/10
# -------------
# train Loss: 0.9287 Acc: 0.7070
# val Loss: 0.8866 Acc: 0.7253
# Epoch 3/10
# -------------
# train Loss: 0.8740 Acc: 0.7280
# val Loss: 0.8498 Acc: 0.7361
# Epoch 4/10
# -------------
# train Loss: 0.8442 Acc: 0.7388
# val Loss: 0.8307 Acc: 0.7451
# Epoch 5/10
# -------------
# train Loss: 0.8265 Acc: 0.7466
# val Loss: 0.8198 Acc: 0.7504
# Epoch 6/10
# -------------
# train Loss: 0.8143 Acc: 0.7531
# val Loss: 0.8119 Acc: 0.7576
# Epoch 7/10
# -------------
# train Loss: 0.8046 Acc: 0.7597
# val Loss: 0.8056 Acc: 0.7576
# Epoch 8/10
# -------------
# train Loss: 0.7968 Acc: 0.7615
# val Loss: 0.8011 Acc: 0.7630
# Epoch 9/10
# -------------
# train Loss: 0.7900 Acc: 0.7639
# val Loss: 0.7977 Acc: 0.7612
# Epoch 10/10
# -------------
# train Loss: 0.7840 Acc: 0.7711
# val Loss: 0.7949 Acc: 0.7594

# %%
print(classification_report(test_ans, test_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       175
#            1       0.78      0.75      0.76       999
#            2       0.73      0.86      0.79      1163
#
#     accuracy                           0.75      2337
#    macro avg       0.50      0.54      0.52      2337
# weighted avg       0.70      0.75      0.72      2337
# /home/ryoyanagimoto/anaconda3/envs/hazumi1902/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ryoyanagimoto/anaconda3/envs/hazumi1902/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ryoyanagimoto/anaconda3/envs/hazumi1902/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(test_ans, test_preds)
print(cm)

sns.heatmap(cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ryoyanagimoto/Hazumi1902/step2/step2_2.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/ryoyanagimoto/Hazumi1902/step2/step2_2.ipynb#ch0000005?line=0'>1</a> cm = confusion_matrix(test_ans, test_preds)
#       <a href='vscode-notebook-cell:/home/ryoyanagimoto/Hazumi1902/step2/step2_2.ipynb#ch0000005?line=1'>2</a> print(cm)
#       <a href='vscode-notebook-cell:/home/ryoyanagimoto/Hazumi1902/step2/step2_2.ipynb#ch0000005?line=3'>4</a> sns.heatmap(cm)
#
# NameError: name 'confusion_matrix' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ryoyanagimoto/Hazumi1902/step2/step2_2.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/ryoyanagimoto/Hazumi1902/step2/step2_2.ipynb#ch0000006?line=0'>1</a> train_target
#
# NameError: name 'train_target' is not defined
